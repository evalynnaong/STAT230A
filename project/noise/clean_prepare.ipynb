# %% [markdown]
# ## Load raw data for noise exceedence occurrences, medical calls, census data:

# %% [markdown]
# ## Clean:

# %% [markdown]
# #### 1) Extract necessary features for the above datasets and rename

# %% [markdown]
# #### 2) Set features to appropriate data types

# %% [markdown]
# ## Prepare data:

# %% [markdown]
# #### 1) Attribute location_id to medical calls

# %% [markdown]
# #### 2) Attribute census data to location_id's? Or to medical calls's based on locations...
# Census data offered by zipcode...can merge on the medical calls based on zipcodes

# %% [markdown]
# #### 3) **Choose some way to merge data**
# Potential ideas:
# - calls within 1 hour of noise exceedences
# - evaluate by date (# of calls and # of noise exceedences per day)
